# %% [markdown]
# # Fetching movies data from tmbd api and forming a dataset
#
# ### Features to be kept from json data ---
#
# - original_title
# - popularity
# - release_date
# - vote_average
# - vote_count
# - original_language
# - id
# - overview
#
# ### Dataset will be of shape -- 10956 * 8

# %%
import pandas as pd
import requests #this library helps to create http requests using python
import os
from dotenv import load_dotenv

# %%
load_dotenv()

api_key = os.getenv("TMDB_API_KEY")

url = f"https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=en-US&page=1"

response = requests.get(url) #-- response code -- 200 means everything working fine, 404 means error

# %%
data = response.json()['results']

df = pd.DataFrame(data)

df
# Out:
#     adult                     backdrop_path            genre_ids       id  \
# 0   False   /zMwhWailP1WY7sb6AoE6b8ugoy.jpg  [12, 16, 10751, 14]  1007757
# 1   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg             [18, 80]      278
# 2   False  /ufSwlnECLoUbBjPrFqEQcWBzHwc.jpg          [10402, 18]   936075
# 3   False  /8Tfys3mDZVp4tNoH2ktm06a0Tau.jpg            [878, 12]   687163
# 4   False  /ejdD20cdHNFAYAN2DlqPToXKyzx.jpg             [18, 80]      238
# 5   False  /bVGHSe47W6oCQL1Q88pvRAet51A.jpg           [18, 9648]  1330021
# 6   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg             [18, 80]      240
# 7   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg      [18, 36, 10752]      424
# 8   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                 [18]      389
# 9   False  /vpuPY4UziUCxv7gYYoaZQ3LX7to.jpg             [28, 53]  1383731
# 10  False  /dyJvKsNs2KP8qQnAXbRwDjblViy.jpg      [16, 10751, 14]      129
# 11  False  /cfT29Im5VDvjE0RpyKOSdCKZal7.jpg         [28, 80, 53]      155
# 12  False  /84beTJf26mfhoasUlKSOiNSutyS.jpg      [35, 18, 10749]    19404
# 13  False  /b6HWTOxn1xevvyHU2K9ICvaRU6g.jpg         [14, 18, 80]      497
# 14  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg         [12, 14, 28]      122
# 15  False  /xyWKrni8WrYzqn7ztvI5nIY0h62.jpg          [35, 10749]  1181678
# 16  False  /wCuUKiRaz0wEESsYqmQy005xvTE.jpg         [35, 53, 18]   496243
# 17  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg         [53, 80, 35]      680
# 18  False  /mMtUybQ6hL24FXo0F3Z4j2KG7kZ.jpg      [16, 10749, 18]   372058
# 19  False  /2ssWTSVklAEc98frZUQhgtGHx7s.jpg        [12, 18, 878]   157336
#
#                                             title original_language  \
# 0                                         Swapped                en
# 1                        The Shawshank Redemption                en
# 2                                         Michael                en
# 3                               Project Hail Mary                en
# 4                                   The Godfather                en
# 5                     Remarkably Bright Creatures                en
# 6                           The Godfather Part II                en
# 7                                Schindler's List                en
# 8                                    12 Angry Men                en
# 9                                       Protector                en
# 10                                  Spirited Away                ja
# 11                                The Dark Knight                en
# 12                    Dilwale Dulhania Le Jayenge                hi
# 13                                 The Green Mile                en
# 14  The Lord of the Rings: The Return of the King                en
# 15                          ¿Quieres ser mi hijo?                en
# 16                                       Parasite                ko
# 17                                   Pulp Fiction                en
# 18                                     Your Name.                ja
# 19                                   Interstellar                en
#
#                                    original_title  \
# 0                                         Swapped
# 1                        The Shawshank Redemption
# 2                                         Michael
# 3                               Project Hail Mary
# 4                                   The Godfather
# 5                     Remarkably Bright Creatures
# 6                           The Godfather Part II
# 7                                Schindler's List
# 8                                    12 Angry Men
# 9                                       Protector
# 10                                       千と千尋の神隠し
# 11                                The Dark Knight
# 12                   दिलवाले दुल्हनिया ले जायेंगे
# 13                                 The Green Mile
# 14  The Lord of the Rings: The Return of the King
# 15                          ¿Quieres ser mi hijo?
# 16                                            기생충
# 17                                   Pulp Fiction
# 18                                          君の名は。
# 19                                   Interstellar
#
#                                              overview  popularity  \
# 0   A small woodland creature and a majestic bird,...    144.0851
# 1   Imprisoned in the 1940s for the double murder ...     85.8959
# 2   The story of Michael Jackson, one of the most ...    375.7553
# 3   Science teacher Ryland Grace wakes up on a spa...    130.2689
# 4   Spanning the years 1945 to 1955, a chronicle o...     38.1806
# 5   Through unlikely bonds formed during night shi...     28.3219
# 6   In the continuing saga of the Corleone crime f...     26.6729
# 7   The true story of how businessman Oskar Schind...     21.5928
# 8   The defense and the prosecution have rested an...     20.5981
# 9   Nikki's life is shattered when her daughter is...     23.5234
# 10  A young girl, Chihiro, becomes trapped in a st...     35.3963
# 11  Batman raises the stakes in his war on crime. ...     48.6339
# 12  Raj is a rich, carefree, happy-go-lucky second...     15.3454
# 13  A supernatural tale set on death row in a Sout...     26.6886
# 14  As armies mass for a final battle that will de...     37.4743
# 15  Lu, a conformist woman in her forties, learns ...      9.1771
# 16  All unemployed, Ki-taek's family takes peculia...     34.6826
# 17  A burger-loving hit man, his philosophical par...     37.9801
# 18  High schoolers Mitsuha and Taki are complete s...     29.8759
# 19  The adventures of a group of explorers who mak...     65.3753
#
#                          poster_path release_date  softcore  video  \
# 0   /tHhxWxge06goXU6ZQH1hj7vK8Hd.jpg   2026-05-01     False  False
# 1   /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23     False  False
# 2   /zm0KAbOjlt9eR5y7vDiL2dEOwMl.jpg   2026-04-22     False  False
# 3   /yihdXomYb5kTeSivtFndMy5iDmf.jpg   2026-03-15     False  False
# 4   /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14     False  False
# 5   /9HcEqn3D4J6b2Z0jK54id9nA0fr.jpg   2026-05-07     False  False
# 6   /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20     False  False
# 7   /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15     False  False
# 8   /zhG3vKWyDRaZYoaww1UVAi29T9h.jpg   1957-04-10     False  False
# 9   /icOZpnGuH9YrEaW3wrw5GJaXGih.jpg   2026-02-20     False  False
# 10  /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20     False  False
# 11  /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-16     False  False
# 12  /tFbfCkS7q6g96wVoAu8kyr93iPm.jpg   1995-10-20     False  False
# 13  /8VG8fDNiy50H4FedGwdSVUPoaJe.jpg   1999-12-10     False  False
# 14  /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg   2003-12-17     False  False
# 15  /6PQJsmuvSMZQMmlJfTpjIkrizUh.jpg   2023-09-21     False  False
# 16  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30     False  False
# 17  /vQWk5YBFWF4bZaofAbv0tShwBvQ.jpg   1994-09-10     False  False
# 18  /q719jXXEzOoYaps6babgKnONONX.jpg   2016-07-01     False  False
# 19  /yQvGrMoipbRoddT0ZR8tPoR7NfX.jpg   2014-11-05     False  False
#
#     vote_average  vote_count
# 0          9.000        1794
# 1          8.723       30623
# 2          8.691        2995
# 3          8.690        5379
# 4          8.700       23076
# 5          8.572         665
# 6          8.600       13993
# 7          8.570       17542
# 8          8.563       10064
# 9          8.540         354
# 10         8.500       18451
# 11         8.531       35960
# 12         8.510        4598
# 13         8.506       19359
# 14         8.500       26699
# 15         8.500         355
# 16         8.500       20779
# 17         8.500       30330
# 18         8.481       12645
# 19         8.479       40107
